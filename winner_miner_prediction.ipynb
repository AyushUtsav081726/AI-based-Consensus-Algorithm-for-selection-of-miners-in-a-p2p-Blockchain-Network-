# %%
import pandas as pd
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('BCdataset_v1.csv') #Importind generated data in the data frame

# %%
pd.set_option('display.max_rows',500)

# %%
df
# Out:
#        Blocks  Age  Faults   Time  Result  Output
# 0           1    0       0     50   0.039       1
# 1           1    0       3     50   0.010       0
# 2           1    0       0     50   0.039       0
# 3           1    0       0     50   0.039       0
# 4           1    0       0     50   0.039       0
# ...       ...  ...     ...    ...     ...     ...
# 79987    1295    3       0  48931   0.013       0
# 79988    1295    4       0  49782   0.019       0
# 79989    1294    0       0  49379   0.002       0
# 79990    1293    7       0  49176   0.049       1
# 79991     983    2      20  36543   0.006       0
#
# [79992 rows x 6 columns]

# %%
df.head(100)
# Out:
#     Blocks  Age  Faults  Time  Result  Output
# 0        1    0       0    50   0.039       1
# 1        1    0       3    50   0.010       0
# 2        1    0       0    50   0.039       0
# 3        1    0       0    50   0.039       0
# 4        1    0       0    50   0.039       0
# 5        1    0       0    50   0.039       0
# 6        1    0       0    50   0.039       0
# 7        1    0      20    50   0.002       0
# 8        2    0       0    73   0.052       0
# 9        1    1       3    50   0.022       0
# 10       1    1       0    50   0.088       1
# 11       1    1       0    50   0.088       0
# 12       1    1       0    50   0.088       0
# 13       1    1       0    50   0.088       0
# 14       1    1       0    50   0.088       0
# 15       1    1      20    50   0.004       0
# 16       2    1       0    73   0.130       0
# 17       1    2       3    50   0.047       0
# 18       2    0       0    90   0.043       0
# ...

# %%
df.shape
# Out:
# (79992, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79992 entries, 0 to 79991
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Blocks  79992 non-null  int64
#  1   Age     79992 non-null  int64
#  2   Faults  79992 non-null  int64
#  3   Time    79992 non-null  int64
#  4   Result  79992 non-null  float64
#  5   Output  79992 non-null  int64
# dtypes: float64(1), int64(5)
# memory usage: 3.7 MB

# %%
((df.isnull().sum()/df.shape[0])*100).sort_values(ascending=False)
# Out:
# Blocks    0.0
# Age       0.0
# Faults    0.0
# Time      0.0
# Result    0.0
# Output    0.0
# dtype: float64

# %%
df.corr()
# Out:
#           Blocks       Age    Faults      Time    Result    Output
# Blocks  1.000000 -0.058736 -0.190308  0.999538 -0.469472  0.003814
# Age    -0.058736  1.000000  0.193324 -0.059039  0.497397  0.518129
# Faults -0.190308  0.193324  1.000000 -0.198059 -0.042737 -0.030810
# Time    0.999538 -0.059039 -0.198059  1.000000 -0.466478  0.003933
# Result -0.469472  0.497397 -0.042737 -0.466478  1.000000  0.346264
# Output  0.003814  0.518129 -0.030810  0.003933  0.346264  1.000000

# %%
corr_matrix = df.corr()
fig, ax = plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr_matrix,
                annot=True,linewidth=0.5,fmt=".2f",cmap="YlGnBu");

# %%
df["Output"].value_counts()
# Out:
# 0    69993
# 1     9999
# Name: Output, dtype: int64

# %%
plt.style.use('ggplot')
df["Output"].value_counts().plot(kind="bar",color=["salmon","lightblue"]);
plt.title("Miner vs Non Minor ");

# %%
df["Age"].value_counts()
# Out:
# 0     10006
# 1     10004
# 2     10002
# 3     10000
# 4      9998
# 5      9993
# 6      9902
# 7      7780
# 8       992
# 9       484
# 10      288
# 11      174
# 12      115
# 13       74
# 14       49
# 15       26
# 16       24
# 17       20
# 18       19
# 19       14
# 20       10
# 21        5
# 22        4
# 23        2
# 24        1
# 25        1
# 26        1
# 27        1
# 28        1
# 29        1
# 30        1
# Name: Age, dtype: int64

# %%
plt.style.use('ggplot')
df["Age"].value_counts().plot(kind="bar",color=["salmon","lightblue"]);
plt.title("Age of the minor ");

# %%
#Relationship b/w age and output
pd.crosstab(df.Age,df.Output)
# Out:
# Output      0     1
# Age
# 0       10005     1
# 1       10003     1
# 2       10001     1
# 3        9999     1
# 4        9994     4
# 5        9903    90
# 6        7781  2121
# 7         992  6788
# 8         484   508
# 9         288   196
# 10        174   114
# 11        115    59
# 12         74    41
# 13         49    25
# 14         26    23
# 15         24     2
# 16         20     4
# 17         19     1
# 18         14     5
# 19         10     4
# 20          5     5
# 21          4     1
# 22          2     2
# 23          1     1
# 24          1     0
# 25          1     0
# 26          1     0
# 27          1     0
# 28          1     0
# 29          1     0
# 30          0     1

# %%
#Create a plot of relationship b/w age and output
pd.crosstab(df.Output,df.Age).plot(kind="bar",
                                    figsize=(10,6),
                                    color=["salmon","lightblue"])
plt.title("Relationship b/w age and minors who mined or not")
plt.ylabel("Age")
plt.xlabel("Mined or not")
plt.legend(["Mined","Not Mined"]);
plt.xticks(rotation=0);

# %%
scatter(df.Age, df.Output)
np.corrcoef(df.Age, df.Output)
plt.title("Scatter Plot b/w age of minor and mined or not")
plt.xlabel("age of minor")
plt.ylabel("mined or not");

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

#Novel evaluations 
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.model_selection import RandomizedSearchCV ,GridSearchCV
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import precision_score,recall_score ,f1_score
from sklearn.metrics import plot_roc_curve
from sklearn import preprocessing
from sklearn import metrics
from sklearn.inspection import permutation_importance

# %%
#Splitting the data into X and Y
X = df.drop("Output" ,axis =1)

Y =df["Output"]

# %%
X
# Out:
#        Blocks  Age  Faults   Time  Result
# 0           1    0       0     50   0.039
# 1           1    0       3     50   0.010
# 2           1    0       0     50   0.039
# 3           1    0       0     50   0.039
# 4           1    0       0     50   0.039
# ...       ...  ...     ...    ...     ...
# 79987    1295    3       0  48931   0.013
# 79988    1295    4       0  49782   0.019
# 79989    1294    0       0  49379   0.002
# 79990    1293    7       0  49176   0.049
# 79991     983    2      20  36543   0.006
#
# [79992 rows x 5 columns]

# %%
Y
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 79987    0
# 79988    0
# 79989    0
# 79990    1
# 79991    0
# Name: Output, Length: 79992, dtype: int64

# %%
#split data into train and test sets
np.random.seed(42)

#split into train and test set
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)

# %%
X_train
# Out:
#        Blocks  Age  Faults   Time  Result
# 33825     525    2       3  19627   0.015
# 37464     620    2       0  22856   0.015
# 70090    1139    0       0  44019   0.002
# 26458     442    7       0  17540   0.135
# 593         7    4       3    251   0.170
# ...       ...  ...     ...    ...     ...
# 6265       82    8       3   2435   0.407
# 54886     896    7       0  34010   0.070
# 76820    1245    7       0  47809   0.051
# 860        17    7       0    657   1.168
# 15795     270    2       0   9932   0.033
#
# [63993 rows x 5 columns]

# %%
y_train
# Out:
# 33825    0
# 37464    0
# 70090    0
# 26458    1
# 593      0
#         ..
# 6265     1
# 54886    1
# 76820    1
# 860      1
# 15795    0
# Name: Output, Length: 63993, dtype: int64

# %%
models = {"Logistic Regression":LogisticRegression(),
         "KNN":KNeighborsClassifier(),
         "Random Forest":RandomForestClassifier()}
#Create a function to fit and score models

def fit_and_score(models, X_train,X_test,y_train,y_test):
    
    """
    Fits and  evaluates given machine learning learning models.
    models : a dict of different Scikit-Learn machine learning models
    X_train : training data (no label)
    X_test : testing data(no labels)
    y_test : training data labels
    y_test : test labels
    
    """
    
    #set random seed
    np.random.seed(42)
    #Make a dictionary models
    model_scores = {}
    #Loop through models
    for name, model in models.items():
       #Fit the model to the data 
       model.fit(X_train,y_train)
       #Evaluate the model and append its score to model_scores
       model_scores[name] = model.score(X_test,y_test)
    return model_scores

# %%
model_scores = fit_and_score(models= models,
                            X_train =X_train,
                            X_test = X_test,
                            y_train = y_train,
                            y_test=y_test)
model_scores
# Out:
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# {'Logistic Regression': 0.949496843552722,
#  'KNN': 0.8770548159259953,
#  'Random Forest': 0.9624976561035065}

# %%
model_compare = pd.DataFrame(model_scores, index=["accuracy"])
model_compare.T.plot.bar();
